# %% [markdown]
# ## Word Cloud of The Big Book of Alcoholics Anonymous

# %%
# Dependencies
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Const
wordcloud = WordCloud(width=1000, height=500, background_color='white').generate(text)

# %%
# Source
import fitz  # PyMuPDF

# Load the PDF
doc = fitz.open("AA Big Book.pdf")

# Extract all text
text = ""
for page in doc:
    text += page.get_text()

doc.close()

# %%
# Plot
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
